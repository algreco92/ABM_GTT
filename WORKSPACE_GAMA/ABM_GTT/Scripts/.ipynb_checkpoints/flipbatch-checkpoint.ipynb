# %%
# %pylab inline
import csv, re
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
experiments = []
percorso = "../models/exports/batch_flip/"
for i in [0.0,0.25,0.5,0.75,1.0]:
    print str(i)
    experiments.append(pd.read_csv(percorso + "ticket_trend_0_"+str(i)+".csv",header=False, names=['Time','1','2','3','4','Abbonati','Utility','Total_risk']))
# Out:
# 0.0
# 0.25
# 0.5
# 0.75
# 1.0

# %%
plot(linspace(0.0,1.0,5),[caco['Total_risk'][len(caco)-1]for caco in experiments],'bo')
plt.xlim(xmin=-0.1,xmax=1.1)
# Out:
# (-0.1, 1.1)

# %%
fig = plt.figure(1, figsize=(15, 6))
ax = fig.add_subplot(111)
for i in linspace(0,1,5):
    graph = ax.plot(experiments[int(4*i)]['Total_risk'],label='flip = '+str(i), linewidth=2)
plt.legend(loc=3)
plt.xlabel('Time',fontsize=18)
plt.ylabel('Total_risk',fontsize=18)
plt.xlim(xmax=255)
plt.savefig("batchflip.png")
