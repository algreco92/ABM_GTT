# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("../models/exports/23_11/ticket_trend_0_25.csv",header= False,names=['Time','1','2','3','4','Abbonati','Utility','Total_risk'])

# %%
fig = plt.figure(0,figsize=(20,10))
ax = fig.add_subplot(111)
ax.set_xlim(146000,218000)
graph = ax.plot(df['Time'],df['Utility'], linewidth=2)
